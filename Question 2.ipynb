# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import sys
sys.setrecursionlimit(10**8)
def f(n):
    if n==0:
        return 0
    else:
        return(600 + 1.5*(1-600)/1000*600 * f(n-1))

# %%
x = []
y = []
for n in range(0,50):
    y.append(f(n))
    x.append(n)

# %%
plt.plot(x,y)
plt.title("Lizard Population vs Years ")
plt.ylabel('Population')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')
